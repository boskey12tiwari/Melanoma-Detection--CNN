# %% [markdown]
# Problem statement: To build a CNN based model which can accurately detect melanoma. Melanoma is a type of cancer that can be deadly if not detected early. It accounts for 75% of skin cancer deaths. A solution which can evaluate images and alert the dermatologists about the presence of melanoma has the potential to reduce a lot of manual effort needed in diagnosis.

# %% [markdown]
# ### Importing Skin Cancer Data
# #### To do: Take necessary actions to read the data

# %% [markdown]
# ### Importing all the important libraries

# %%
import pathlib
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os
import PIL
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential

# %%
## If you are using the data by mounting the google drive, use the following :
from google.colab import drive
drive.mount('/content/gdrive')

##Ref:https://towardsdatascience.com/downloading-datasets-into-google-drive-via-google-colab-bcb1b30b0166
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %% [markdown]
# This assignment uses a dataset of about 2357 images of skin cancer types. The dataset contains 9 sub-directories in each train and test subdirectories. The 9 sub-directories contains the images of 9 skin cancer types respectively.

# %%
# Defining the path for train and test images
## Todo: Update the paths of the train and test dataset
data_dir_train = pathlib.Path("/content/gdrive/MyDrive/CNN/Train")
data_dir_test = pathlib.Path('/content/gdrive/MyDrive/CNN/Test')

# %%
image_count_train = len(list(data_dir_train.glob('*/*.jpg')))
print(image_count_train)
image_count_test = len(list(data_dir_test.glob('*/*.jpg')))
print(image_count_test)
# Out:
# 2239
# 118

# %% [markdown]
# ### Load using keras.preprocessing
#
# Let's load these images off disk using the helpful image_dataset_from_directory utility.

# %% [markdown]
# ### Create a dataset
#
# Define some parameters for the loader:

# %%
batch_size = 32
img_height = 180
img_width = 180

# %% [markdown]
# Use 80% of the images for training, and 20% for validation.

# %%
## Write your train dataset here
## Note use seed=123 while creating your dataset using tf.keras.preprocessing.image_dataset_from_directory
## Note, make sure your resize your images to the size img_height*img_width, while writting the dataset
train_ds =tf.keras.preprocessing.image_dataset_from_directory(
    data_dir_train,
    seed=123,
    validation_split= 0.2,
    subset= 'training',
    image_size=(img_height,img_width),
    batch_size = batch_size
)
# Out:
# Found 2239 files belonging to 9 classes.
# Using 1792 files for training.

# %%
## Write your validation dataset here
## Note use seed=123 while creating your dataset using tf.keras.preprocessing.image_dataset_from_directory
## Note, make sure your resize your images to the size img_height*img_width, while writting the dataset
val_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir_train,
  validation_split=0.2,
  subset="validation",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 2239 files belonging to 9 classes.
# Using 447 files for validation.

# %%
# List out all the classes of skin cancer and store them in a list. 
# You can find the class names in the class_names attribute on these datasets. 
# These correspond to the directory names in alphabetical order.
class_names = train_ds.class_names
print(class_names)
# Out:
# ['actinic keratosis', 'basal cell carcinoma', 'dermatofibroma', 'melanoma', 'nevus', 'pigmented benign keratosis', 'seborrheic keratosis', 'squamous cell carcinoma', 'vascular lesion']

# %% [markdown]
# ### Visualize the data
# #### Todo, create a code to visualize one instance of all the nine classes present in the dataset

# %%
import matplotlib.pyplot as plt

import matplotlib.pyplot as plt
plt.figure(figsize=(10,10))
for i in range(9): 
  plt.subplot(3, 3, i + 1)
  image = plt.imread(str(list(data_dir_train.glob(class_names[i]+'/*.jpg'))[1]))
  plt.title(class_names[i])
  plt.imshow(image)

### your code goes here, you can use training or validation data to visualize

# %% [markdown]
# The `image_batch` is a tensor of the shape `(32, 180, 180, 3)`. This is a batch of 32 images of shape `180x180x3` (the last dimension refers to color channels RGB). The `label_batch` is a tensor of the shape `(32,)`, these are corresponding labels to the 32 images.

# %% [markdown]
# `Dataset.cache()` keeps the images in memory after they're loaded off disk during the first epoch.
#
# `Dataset.prefetch()` overlaps data preprocessing and model execution while training.

# %%
AUTOTUNE = tf.data.experimental.AUTOTUNE
train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %% [markdown]
# ### Create the model
# #### Todo: Create a CNN model, which can accurately detect 9 classes present in the dataset. Use ```layers.experimental.preprocessing.Rescaling``` to normalize pixel values between (0,1). The RGB channel values are in the `[0, 255]` range. This is not ideal for a neural network. Here, it is good to standardize values to be in the `[0, 1]`

# %%
### Your code goes here

from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPool2D
num_classes = 9
model = Sequential([
                    layers.experimental.preprocessing.Rescaling(1./255, input_shape=(img_height, img_width,3))
])
model.add(Conv2D(filters = 32, kernel_size = (5,5),padding = 'Same', 
                 activation ='relu', input_shape = (180, 180, 32)))
model.add(Conv2D(filters = 32, kernel_size = (5,5),padding = 'Same', 
                 activation ='relu'))
model.add(MaxPool2D(pool_size=(2,2)))
model.add(Conv2D(filters = 32, kernel_size = (5,5),padding = 'Same', 
                 activation ='relu'))
model.add(MaxPool2D(pool_size=(2,2)))
model.add(Conv2D(filters = 64, kernel_size = (5,5),padding = 'Same', 
                 activation ='relu'))
model.add(MaxPool2D(pool_size=(2,2)))
model.add(Conv2D(filters = 64, kernel_size = (5,5),padding = 'Same', 
                 activation ='relu'))
model.add(MaxPool2D(pool_size=(2,2)))
model.add(Dropout(0.25))


model.add(Flatten())
model.add(Dense(num_classes, activation = "softmax"))

# %% [markdown]
# ### Compile the model
# Choose an appropirate optimiser and loss function for model training

# %%
### Todo, choose an appropirate optimiser and loss function
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
# View the summary of all layers
model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling_3 (Rescaling)     (None, 180, 180, 3)       0
#
#  conv2d_14 (Conv2D)          (None, 180, 180, 32)      2432
#
#  conv2d_15 (Conv2D)          (None, 180, 180, 32)      25632
#
#  max_pooling2d_11 (MaxPoolin  (None, 90, 90, 32)       0
#  g2D)
#
#  conv2d_16 (Conv2D)          (None, 90, 90, 32)        25632
#
#  max_pooling2d_12 (MaxPoolin  (None, 45, 45, 32)       0
#  g2D)
#
#  conv2d_17 (Conv2D)          (None, 45, 45, 64)        51264
#
#  max_pooling2d_13 (MaxPoolin  (None, 22, 22, 64)       0
#  g2D)
#
#  conv2d_18 (Conv2D)          (None, 22, 22, 64)        102464
#
#  max_pooling2d_14 (MaxPoolin  (None, 11, 11, 64)       0
#  g2D)
#
#  dropout_3 (Dropout)         (None, 11, 11, 64)        0
#
#  flatten_3 (Flatten)         (None, 7744)              0
#
#  dense_3 (Dense)             (None, 9)                 69705
#
# =================================================================
# Total params: 277,129
# Trainable params: 277,129
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Train the model

# %%
epochs = 30
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/20
# 56/56 [==============================] - 18s 127ms/step - loss: 2.0942 - accuracy: 0.1998 - val_loss: 2.0250 - val_accuracy: 0.2304
# Epoch 2/20
# 56/56 [==============================] - 4s 77ms/step - loss: 1.9531 - accuracy: 0.2545 - val_loss: 1.8239 - val_accuracy: 0.3378
# Epoch 3/20
# 56/56 [==============================] - 4s 76ms/step - loss: 1.8376 - accuracy: 0.3276 - val_loss: 1.7968 - val_accuracy: 0.3400
# Epoch 4/20
# 56/56 [==============================] - 4s 77ms/step - loss: 1.7338 - accuracy: 0.3850 - val_loss: 1.9464 - val_accuracy: 0.2573
# Epoch 5/20
# 56/56 [==============================] - 4s 77ms/step - loss: 1.7616 - accuracy: 0.3438 - val_loss: 1.6469 - val_accuracy: 0.3870
# Epoch 6/20
# 56/56 [==============================] - 4s 77ms/step - loss: 1.6469 - accuracy: 0.3968 - val_loss: 1.5918 - val_accuracy: 0.4273
# Epoch 7/20
# 56/56 [==============================] - 4s 77ms/step - loss: 1.5696 - accuracy: 0.4185 - val_loss: 1.6480 - val_accuracy: 0.4139
# Epoch 8/20
# 56/56 [==============================] - 4s 77ms/step - loss: 1.4866 - accuracy: 0.4621 - val_loss: 1.4779 - val_accuracy: 0.4899
# Epoch 9/20
# 56/56 [==============================] - 4s 77ms/step - loss: 1.4511 - accuracy: 0.4967 - val_loss: 1.4710 - val_accuracy: 0.4743
# Epoch 10/20
# 56/56 [==============================] - 4s 77ms/step - loss: 1.3557 - accuracy: 0.5089 - val_loss: 1.5620 - val_accuracy: 0.4407
# Epoch 11/20
# 56/56 [==============================] - 4s 77ms/step - loss: 1.3360 - accuracy: 0.5128 - val_loss: 1.5029 - val_accuracy: 0.4922
# Epoch 12/20
# 56/56 [==============================] - 4s 77ms/step - loss: 1.4073 - accuracy: 0.4894 - val_loss: 1.5388 - val_accuracy: 0.4810
# Epoch 13/20
# 56/56 [==============================] - 4s 77ms/step - loss: 1.2326 - accuracy: 0.5541 - val_loss: 1.4802 - val_accuracy: 0.4966
# Epoch 14/20
# 56/56 [==============================] - 4s 78ms/step - loss: 1.2641 - accuracy: 0.5580 - val_loss: 1.7445 - val_accuracy: 0.4161
# Epoch 15/20
# 56/56 [==============================] - 4s 77ms/step - loss: 1.1314 - accuracy: 0.5882 - val_loss: 1.5279 - val_accuracy: 0.4765
# Epoch 16/20
# 56/56 [==============================] - 4s 77ms/step - loss: 1.0651 - accuracy: 0.6122 - val_loss: 1.6016 - val_accuracy: 0.4832
# Epoch 17/20
# 56/56 [==============================] - 4s 77ms/step - loss: 1.0118 - accuracy: 0.6189 - val_loss: 1.6583 - val_accuracy: 0.4832
# Epoch 18/20
# 56/56 [==============================] - 4s 77ms/step - loss: 0.9658 - accuracy: 0.6429 - val_loss: 1.7653 - val_accuracy: 0.4295
# Epoch 19/20
# 56/56 [==============================] - 4s 77ms/step - loss: 0.9324 - accuracy: 0.6674 - val_loss: 1.7119 - val_accuracy: 0.4832
# Epoch 20/20
# 56/56 [==============================] - 4s 77ms/step - loss: 0.8856 - accuracy: 0.6696 - val_loss: 2.0875 - val_accuracy: 0.4027

# %% [markdown]
# ### Visualizing training results

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# #### Todo: Write your findings after the model fit, see if there is an evidence of model overfit or underfit
#
# Accuracy of the model on train data 60% but on test it is 40%. So need to add more layer,neurons or adding dropout layers.
#
# Model is overfit as we can see low error in the training set and a higher error in the testing set.. the  and we need to choose correct augmentation strategy

# %%
loss, accuracy = model.evaluate(train_ds, verbose=1,)
loss_v, accuracy_v = model.evaluate(val_ds, verbose=1)

print("Accuracy: ", accuracy)
print("Validation Accuracy: ",accuracy_v)
print("Loss: ",loss)
print("Validation Loss", loss_v)
# Out:
# 56/56 [==============================] - 2s 28ms/step - loss: 1.1239 - accuracy: 0.6032
# 14/14 [==============================] - 0s 27ms/step - loss: 2.0875 - accuracy: 0.4027
# Accuracy:  0.6032366156578064
# Validation Accuracy:  0.4026845693588257
# Loss:  1.1238616704940796
# Validation Loss 2.087514638900757

# %% [markdown]
# ### Write your findings here

# %%
# Todo, after you have analysed the model fit history for presence of underfit or overfit, choose an appropriate data augumentation strategy. 
# Your code goes here

data_augument = keras.Sequential([
                             layers.experimental.preprocessing.RandomFlip(mode="horizontal_and_vertical",input_shape=(img_height,img_width,3)),
                             layers.experimental.preprocessing.RandomRotation(0.2, fill_mode='reflect'),
                             layers.experimental.preprocessing.RandomZoom(height_factor=(0.2, 0.3), width_factor=(0.2, 0.3), fill_mode='reflect')
])

# %%
# Todo, visualize how your augmentation strategy works for one instance of training image.

plt.figure(figsize=(12, 12))
for images, labels in train_ds.take(1):
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(data_augument(images)[i].numpy().astype("uint8"))
        plt.title(class_names[labels[i]])
        plt.axis("off")

# %% [markdown]
# ### Todo:
# ### Create the model, compile and train the model

# %%
## You can use Dropout layer if there is an evidence of overfitting in your findings

from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPool2D
num_classes = 9
model = Sequential([ data_augument,
                    layers.experimental.preprocessing.Rescaling(1./255, input_shape=(img_height, img_width,3))
      
])
model.add(Conv2D(filters = 32, kernel_size = (5,5),padding = 'Same', 
                 activation ='relu', input_shape = (180, 180, 32)))
model.add(Conv2D(filters = 32, kernel_size = (5,5),padding = 'Same', 
                 activation ='relu'))
model.add(MaxPool2D(pool_size=(2,2)))
model.add(Conv2D(filters = 64, kernel_size = (5,5),padding = 'Same', 
                 activation ='relu'))
model.add(MaxPool2D(pool_size=(2,2)))
model.add(Conv2D(filters = 64, kernel_size = (5,5),padding = 'Same', 
                 activation ='relu'))
model.add(MaxPool2D(pool_size=(2,2)))
model.add(Dropout(0.25))


model.add(Flatten())
model.add(Dense(num_classes, activation = "softmax"))

# %% [markdown]
# ### Compiling the model

# %%
## Your code goes here
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %% [markdown]
# ### Training the model

# %%
## Your code goes here, note: train your model for 20 epochs
epochs=30
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/30
# 56/56 [==============================] - 6s 89ms/step - loss: 2.0598 - accuracy: 0.2031 - val_loss: 2.0347 - val_accuracy: 0.2058
# Epoch 2/30
# 56/56 [==============================] - 5s 86ms/step - loss: 2.0371 - accuracy: 0.2176 - val_loss: 2.0491 - val_accuracy: 0.2058
# Epoch 3/30
# 56/56 [==============================] - 5s 86ms/step - loss: 2.0230 - accuracy: 0.2042 - val_loss: 2.0324 - val_accuracy: 0.1924
# Epoch 4/30
# 56/56 [==============================] - 5s 86ms/step - loss: 2.0558 - accuracy: 0.2093 - val_loss: 2.0263 - val_accuracy: 0.2036
# Epoch 5/30
# 56/56 [==============================] - 5s 86ms/step - loss: 2.0178 - accuracy: 0.1953 - val_loss: 2.0259 - val_accuracy: 0.2058
# Epoch 6/30
# 56/56 [==============================] - 5s 86ms/step - loss: 2.0197 - accuracy: 0.2081 - val_loss: 2.0346 - val_accuracy: 0.2058
# Epoch 7/30
# 56/56 [==============================] - 5s 86ms/step - loss: 2.0150 - accuracy: 0.1992 - val_loss: 2.0268 - val_accuracy: 0.2036
# Epoch 8/30
# 56/56 [==============================] - 5s 86ms/step - loss: 2.0157 - accuracy: 0.2020 - val_loss: 2.0263 - val_accuracy: 0.2036
# Epoch 9/30
# 56/56 [==============================] - 5s 89ms/step - loss: 2.0156 - accuracy: 0.2137 - val_loss: 2.0368 - val_accuracy: 0.2036
# Epoch 10/30
# 56/56 [==============================] - 5s 85ms/step - loss: 2.0190 - accuracy: 0.1987 - val_loss: 2.0196 - val_accuracy: 0.2036
# Epoch 11/30
# 56/56 [==============================] - 5s 85ms/step - loss: 2.0097 - accuracy: 0.2422 - val_loss: 1.9666 - val_accuracy: 0.3244
# Epoch 12/30
# 56/56 [==============================] - 5s 85ms/step - loss: 2.0237 - accuracy: 0.2121 - val_loss: 2.0246 - val_accuracy: 0.2036
# Epoch 13/30
# 56/56 [==============================] - 5s 85ms/step - loss: 2.0175 - accuracy: 0.2081 - val_loss: 2.0267 - val_accuracy: 0.2036
# Epoch 14/30
# 56/56 [==============================] - 5s 85ms/step - loss: 2.0151 - accuracy: 0.2020 - val_loss: 2.0271 - val_accuracy: 0.2058
# Epoch 15/30
# 56/56 [==============================] - 5s 85ms/step - loss: 2.0166 - accuracy: 0.1931 - val_loss: 2.0214 - val_accuracy: 0.2058
# Epoch 16/30
# 56/56 [==============================] - 5s 85ms/step - loss: 2.0177 - accuracy: 0.1981 - val_loss: 2.0245 - val_accuracy: 0.2036
# Epoch 17/30
# 56/56 [==============================] - 5s 85ms/step - loss: 2.0152 - accuracy: 0.2126 - val_loss: 2.0402 - val_accuracy: 0.2103
# Epoch 18/30
# 56/56 [==============================] - 5s 85ms/step - loss: 2.0173 - accuracy: 0.2171 - val_loss: 2.0192 - val_accuracy: 0.2103
# Epoch 19/30
# 56/56 [==============================] - 5s 86ms/step - loss: 2.0257 - accuracy: 0.2115 - val_loss: 2.0273 - val_accuracy: 0.1924
# Epoch 20/30
# 56/56 [==============================] - 5s 86ms/step - loss: 2.0149 - accuracy: 0.2098 - val_loss: 2.0255 - val_accuracy: 0.2036
# Epoch 21/30
# 56/56 [==============================] - 5s 86ms/step - loss: 2.0138 - accuracy: 0.2087 - val_loss: 2.0240 - val_accuracy: 0.2081
# Epoch 22/30
# 56/56 [==============================] - 5s 86ms/step - loss: 2.0149 - accuracy: 0.2093 - val_loss: 2.0301 - val_accuracy: 0.2036
# Epoch 23/30
# 56/56 [==============================] - 5s 87ms/step - loss: 2.0143 - accuracy: 0.2081 - val_loss: 2.0713 - val_accuracy: 0.1902
# Epoch 24/30
# 56/56 [==============================] - 5s 86ms/step - loss: 2.0425 - accuracy: 0.1864 - val_loss: 2.0232 - val_accuracy: 0.1924
# Epoch 25/30
# 56/56 [==============================] - 5s 87ms/step - loss: 2.0146 - accuracy: 0.1975 - val_loss: 2.0277 - val_accuracy: 0.2058
# Epoch 26/30
# 56/56 [==============================] - 5s 86ms/step - loss: 2.0139 - accuracy: 0.2065 - val_loss: 2.0255 - val_accuracy: 0.2058
# Epoch 27/30
# 56/56 [==============================] - 5s 87ms/step - loss: 2.0155 - accuracy: 0.2087 - val_loss: 2.0259 - val_accuracy: 0.2058
# Epoch 28/30
# 56/56 [==============================] - 5s 87ms/step - loss: 2.0137 - accuracy: 0.2121 - val_loss: 2.0251 - val_accuracy: 0.2081
# Epoch 29/30
# 56/56 [==============================] - 5s 87ms/step - loss: 2.0171 - accuracy: 0.1925 - val_loss: 2.0332 - val_accuracy: 0.2058
# Epoch 30/30
# 56/56 [==============================] - 5s 86ms/step - loss: 2.0155 - accuracy: 0.2048 - val_loss: 2.0364 - val_accuracy: 0.2058

# %% [markdown]
# ### Visualizing the results

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
loss, accuracy = model.evaluate(train_ds, verbose=1,)
loss_v, accuracy_v = model.evaluate(val_ds, verbose=1)

print("Accuracy: ", accuracy)
print("Validation Accuracy: ",accuracy_v)
print("Loss: ",loss)
print("Validation Loss", loss_v)
# Out:
# 56/56 [==============================] - 2s 30ms/step - loss: 2.0092 - accuracy: 0.2093
# 14/14 [==============================] - 0s 30ms/step - loss: 2.0364 - accuracy: 0.2058
# Accuracy:  0.2092633992433548
# Validation Accuracy:  0.20581655204296112
# Loss:  2.0092246532440186
# Validation Loss 2.0364139080047607

# %% [markdown]
# #### Todo: Write your findings after the model fit, see if there is an evidence of model overfit or underfit. Do you think there is some improvement now as compared to the previous model run?
#
# Accuracy is decreased but we can see overfitting issue resolved after Augmentation.

# %% [markdown]
# #### **Todo:** Find the distribution of classes in the training dataset.
# #### **Context:** Many times real life datasets can have class imbalance, one class can have proportionately higher number of samples compared to the others. Class imbalance can have a detrimental effect on the final model quality. Hence as a sanity check it becomes important to check what is the distribution of classes in the data.

# %%
def class_distribution_count(directory):
    
    #count number of image in each classes
    count= []
    for path in pathlib.Path(directory).iterdir():
        if path.is_dir():
            count.append(len([name for name in os.listdir(path)
                               if os.path.isfile(os.path.join(path, name))]))
    
    #name of the classes
    sub_directory = [name for name in os.listdir(directory)
                    if os.path.isdir(os.path.join(directory, name))]
    
    #return dataframe with image count and class.
    return pd.DataFrame(list(zip(sub_directory,count)),columns =['Class', 'No. of Image'])

df = class_distribution_count(data_dir_train)
df
# Out:
#                         Class  No. of Image
# 0             vascular lesion           139
# 1        seborrheic keratosis            77
# 2                    melanoma           438
# 3     squamous cell carcinoma           181
# 4              dermatofibroma            95
# 5           actinic keratosis           114
# 6        basal cell carcinoma           376
# 7                       nevus           357
# 8  pigmented benign keratosis           462

# %%
import seaborn as sns
plt.figure(figsize=(10, 8))
sns.barplot(x="No. of Image", y="Class", data=df,
            label="Class")

# %%
count=[]
for i in class_names:
    count.append(len(list(data_dir_train.glob(i+'/*.jpg'))))
plt.figure(figsize=(25,10))
plt.bar(class_names,count)
# Out:
# <BarContainer object of 9 artists>

# %% [markdown]
# #### **Todo:** Write your findings here:
# #### - Which class has the least number of samples?
#
# ans-seborrheic keratosis having least number of samples i.e. 77
# #### - Which classes dominate the data in terms proportionate number of samples?
#
# ans- 	pigmented benign keratosis and melanoma  have proprtionate number of classes
# ctinic keratosis and dermatofibroma have proportionate number of classes

# %% [markdown]
# #### **Todo:** Rectify the class imbalance
# #### **Context:** You can use a python package known as `Augmentor` (https://augmentor.readthedocs.io/en/master/) to add more samples across all classes so that none of the classes have very few samples.

# %%
# !pip install Augmentor
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting Augmentor
#   Downloading Augmentor-0.2.10-py2.py3-none-any.whl (38 kB)
# Requirement already satisfied: tqdm>=4.9.0 in /usr/local/lib/python3.7/dist-packages (from Augmentor) (4.64.0)
# Requirement already satisfied: numpy>=1.11.0 in /usr/local/lib/python3.7/dist-packages (from Augmentor) (1.21.6)
# Requirement already satisfied: future>=0.16.0 in /usr/local/lib/python3.7/dist-packages (from Augmentor) (0.16.0)
# Requirement already satisfied: Pillow>=5.2.0 in /usr/local/lib/python3.7/dist-packages (from Augmentor) (7.1.2)
# Installing collected packages: Augmentor
# Successfully installed Augmentor-0.2.10

# %% [markdown]
# To use `Augmentor`, the following general procedure is followed:
#
# 1. Instantiate a `Pipeline` object pointing to a directory containing your initial image data set.<br>
# 2. Define a number of operations to perform on this data set using your `Pipeline` object.<br>
# 3. Execute these operations by calling the `Pipeline’s` `sample()` method.

# %%
path_to_training_dataset="/content/gdrive/MyDrive/CNN/Train/"
import Augmentor
for i in class_names:
    p = Augmentor.Pipeline(path_to_training_dataset + i)
    p.rotate(probability=0.7, max_left_rotation=10, max_right_rotation=10)
    p.sample(500) ## We are adding 500 samples per class to make sure that none of the classes are sparse.
# Out:
# Initialised with 114 image(s) found.
# Output directory set to /content/gdrive/MyDrive/CNN/Train/actinic keratosis/output.
# Processing <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=600x450 at 0x7F942947F3D0>: 100%|██████████| 500/500 [00:19<00:00, 25.68 Samples/s]
# Initialised with 376 image(s) found.
# Output directory set to /content/gdrive/MyDrive/CNN/Train/basal cell carcinoma/output.
# Processing <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=600x450 at 0x7F942A7C7D90>: 100%|██████████| 500/500 [00:18<00:00, 26.45 Samples/s]
# Initialised with 95 image(s) found.
# Output directory set to /content/gdrive/MyDrive/CNN/Train/dermatofibroma/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7F942A7DA090>: 100%|██████████| 500/500 [00:18<00:00, 26.65 Samples/s]
# Initialised with 438 image(s) found.
# Output directory set to /content/gdrive/MyDrive/CNN/Train/melanoma/output.
# Processing <PIL.Image.Image image mode=RGB size=1024x768 at 0x7F9429B55E90>: 100%|██████████| 500/500 [01:30<00:00,  5.52 Samples/s]
# Initialised with 357 image(s) found.
# Output directory set to /content/gdrive/MyDrive/CNN/Train/nevus/output.
# Processing <PIL.Image.Image image mode=RGB size=3072x2304 at 0x7F9429BFD590>: 100%|██████████| 500/500 [01:27<00:00,  5.73 Samples/s]
# Initialised with 462 image(s) found.
# Output directory set to /content/gdrive/MyDrive/CNN/Train/pigmented benign keratosis/output.
# Processing <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=600x450 at 0x7F943E13E910>: 100%|██████████| 500/500 [00:18<00:00, 27.32 Samples/s]
# Initialised with 77 image(s) found.
# Output directory set to /content/gdrive/MyDrive/CNN/Train/seborrheic keratosis/output.
# Processing <PIL.Image.Image image mode=RGB size=1024x768 at 0x7F942947FBD0>: 100%|██████████| 500/500 [00:42<00:00, 11.86 Samples/s]
# Initialised with 181 image(s) found.
# Output directory set to /content/gdrive/MyDrive/CNN/Train/squamous cell carcinoma/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7F943E286D90>: 100%|██████████| 500/500 [00:19<00:00, 26.30 Samples/s]
# Initialised with 139 image(s) found.
# Output directory set to /content/gdrive/MyDrive/CNN/Train/vascular lesion/output.
# Processing <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=600x450 at 0x7F943E0FC090>: 100%|██████████| 500/500 [00:18<00:00, 26.70 Samples/s]

# %% [markdown]
# Augmentor has stored the augmented images in the output sub-directory of each of the sub-directories of skin cancer types.. Lets take a look at total count of augmented images.

# %%
image_count_train = len(list(data_dir_train.glob('*/output/*.jpg')))
print(image_count_train)
# Out:
# 4500

# %% [markdown]
# ### Lets see the distribution of augmented data after adding new images to the original training data.

# %%
from glob import glob
path_list = [x for x in glob(os.path.join(data_dir_train, '*','output', '*.jpg'))]
path_list

# %%
lesion_list_new = [os.path.basename(os.path.dirname(os.path.dirname(y))) for y in glob(os.path.join(data_dir_train, '*','output', '*.jpg'))]
lesion_list_new

# %%
dataframe_dict_new = dict(zip(path_list, lesion_list_new))

# %%
df2 = pd.DataFrame(list(dataframe_dict_new.items()),columns = ['Path','Label'])
new_df=df2
#new_df = original_df.append(df2)

# %%
new_df['Label'].value_counts()
# Out:
# vascular lesion               500
# seborrheic keratosis          500
# melanoma                      500
# squamous cell carcinoma       500
# dermatofibroma                500
# actinic keratosis             500
# basal cell carcinoma          500
# nevus                         500
# pigmented benign keratosis    500
# Name: Label, dtype: int64

# %% [markdown]
# So, now we have added 500 images to all the classes to maintain some class balance. We can add more images as we want to improve training process.

# %% [markdown]
# #### **Todo**: Train the model on the data created using Augmentor

# %%
batch_size = 32
img_height = 180
img_width = 180

# %% [markdown]
# #### **Todo:** Create a training dataset

# %%
#data_dir_train=""
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir_train,
  seed=123,
  validation_split = 0.2, label_mode='categorical',
  subset ='training',
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 6739 files belonging to 9 classes.
# Using 5392 files for training.

# %% [markdown]
# #### **Todo:** Create a validation dataset

# %%
val_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir_train,
  seed=123,
  validation_split = 0.2,label_mode='categorical',
  subset ='validation' ,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 6739 files belonging to 9 classes.
# Using 1347 files for validation.

# %%
AUTOTUNE = tf.data.experimental.AUTOTUNE
train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %% [markdown]
# #### **Todo:** Create your model (make sure to include normalization)

# %%
## your code goes here
model = Sequential()

model.add(layers.experimental.preprocessing.Rescaling(1./255,input_shape=(180,180,3)))   #Rescaling Layer

#First Convulation layer
model.add(layers.Conv2D(32,kernel_size=(3,3),activation='relu'))
model.add(layers.MaxPool2D(pool_size=(2,2)))

#Second Convulation Layer
model.add(layers.Conv2D(64,kernel_size=(3,3),activation='relu'))
model.add(layers.MaxPool2D(pool_size=(2,2)))

#Third Convulation Layer
model.add(layers.Conv2D(128,kernel_size=(3,3),activation='relu'))
model.add(layers.MaxPool2D(pool_size=(2,2)))

#Dropout layer with 50% Fraction of the input units to drop.
model.add(layers.Dropout(0.5))

#Flatten Layer
##Keras.layers.flatten function flattens the multi-dimensional input tensors into a single dimension.
model.add(layers.Flatten())

#Dense Layer
model.add(layers.Dense(128,activation='relu'))

#Dropout layer with 25% Fraction of the input units to drop.
model.add(layers.Dropout(0.25))

#Dense Layer with softmax activation function.
#Softmax is an activation function that scales numbers/logits into probabilities.
model.add(layers.Dense(len(class_names),activation='softmax'))

model.summary()
# Out:
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling_5 (Rescaling)     (None, 180, 180, 3)       0
#
#  conv2d_23 (Conv2D)          (None, 178, 178, 32)      896
#
#  max_pooling2d_18 (MaxPoolin  (None, 89, 89, 32)       0
#  g2D)
#
#  conv2d_24 (Conv2D)          (None, 87, 87, 64)        18496
#
#  max_pooling2d_19 (MaxPoolin  (None, 43, 43, 64)       0
#  g2D)
#
#  conv2d_25 (Conv2D)          (None, 41, 41, 128)       73856
#
#  max_pooling2d_20 (MaxPoolin  (None, 20, 20, 128)      0
#  g2D)
#
#  dropout_5 (Dropout)         (None, 20, 20, 128)       0
#
#  flatten_5 (Flatten)         (None, 51200)             0
#
#  dense_5 (Dense)             (None, 128)               6553728
#
#  dropout_6 (Dropout)         (None, 128)               0
#
#  dense_6 (Dense)             (None, 9)                 1161
#
# =================================================================
# Total params: 6,648,137
# Trainable params: 6,648,137
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# #### **Todo:** Compile your model (Choose optimizer and loss function appropriately)

# %%
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint,EarlyStopping
optimizer = Adam(learning_rate=0.001, beta_1=0.9, beta_2=0.999, epsilon=None, decay=0.0, amsgrad=False)

model.compile(loss='categorical_crossentropy',
                  optimizer=optimizer,
                  metrics=['accuracy'])

# %% [markdown]
# #### **Todo:**  Train your model

# %%
from keras.callbacks import ReduceLROnPlateau
epochs = 50

learning_rate_reduction = ReduceLROnPlateau(monitor='val_accuracy', 
    patience=3, 
    verbose=1, 
    factor=0.5, 
    min_lr=0.00001)

batch_size = 10
history = model.fit(train_ds,
  epochs = epochs, verbose = 1, validation_data=val_ds , callbacks=[learning_rate_reduction])
# Out:
# Epoch 1/50
# 169/169 [==============================] - 36s 74ms/step - loss: 1.8230 - accuracy: 0.3138 - val_loss: 1.5859 - val_accuracy: 0.3905 - lr: 0.0010
# Epoch 2/50
# 169/169 [==============================] - 7s 40ms/step - loss: 1.4788 - accuracy: 0.4345 - val_loss: 1.3353 - val_accuracy: 0.5004 - lr: 0.0010
# Epoch 3/50
# 169/169 [==============================] - 7s 40ms/step - loss: 1.3070 - accuracy: 0.5039 - val_loss: 1.1408 - val_accuracy: 0.5561 - lr: 0.0010
# Epoch 4/50
# 169/169 [==============================] - 7s 40ms/step - loss: 1.1969 - accuracy: 0.5493 - val_loss: 1.0566 - val_accuracy: 0.5924 - lr: 0.0010
# Epoch 5/50
# 169/169 [==============================] - 7s 40ms/step - loss: 1.0766 - accuracy: 0.5983 - val_loss: 1.0324 - val_accuracy: 0.6177 - lr: 0.0010
# Epoch 6/50
# 169/169 [==============================] - 7s 40ms/step - loss: 0.9879 - accuracy: 0.6259 - val_loss: 0.9339 - val_accuracy: 0.6333 - lr: 0.0010
# Epoch 7/50
# 169/169 [==============================] - 7s 40ms/step - loss: 0.8413 - accuracy: 0.6814 - val_loss: 0.8346 - val_accuracy: 0.7105 - lr: 0.0010
# Epoch 8/50
# 169/169 [==============================] - 7s 40ms/step - loss: 0.7768 - accuracy: 0.7105 - val_loss: 0.8311 - val_accuracy: 0.6978 - lr: 0.0010
# Epoch 9/50
# 169/169 [==============================] - 7s 40ms/step - loss: 0.6597 - accuracy: 0.7591 - val_loss: 0.7442 - val_accuracy: 0.7468 - lr: 0.0010
# Epoch 10/50
# 169/169 [==============================] - 7s 40ms/step - loss: 0.5875 - accuracy: 0.7888 - val_loss: 0.7409 - val_accuracy: 0.7520 - lr: 0.0010
# Epoch 11/50
# 169/169 [==============================] - 7s 40ms/step - loss: 0.5298 - accuracy: 0.8010 - val_loss: 0.7480 - val_accuracy: 0.7476 - lr: 0.0010
# Epoch 12/50
# 169/169 [==============================] - 7s 40ms/step - loss: 0.5127 - accuracy: 0.8138 - val_loss: 0.6284 - val_accuracy: 0.8159 - lr: 0.0010
# Epoch 13/50
# 169/169 [==============================] - 7s 40ms/step - loss: 0.4177 - accuracy: 0.8399 - val_loss: 0.6260 - val_accuracy: 0.8174 - lr: 0.0010
# Epoch 14/50
# 169/169 [==============================] - 7s 40ms/step - loss: 0.3845 - accuracy: 0.8587 - val_loss: 0.7361 - val_accuracy: 0.7944 - lr: 0.0010
# Epoch 15/50
# 169/169 [==============================] - 7s 40ms/step - loss: 0.3995 - accuracy: 0.8557 - val_loss: 0.6464 - val_accuracy: 0.8226 - lr: 0.0010
# Epoch 16/50
# 169/169 [==============================] - 7s 39ms/step - loss: 0.3703 - accuracy: 0.8659 - val_loss: 0.6432 - val_accuracy: 0.8159 - lr: 0.0010
# Epoch 17/50
# 169/169 [==============================] - 7s 39ms/step - loss: 0.3948 - accuracy: 0.8505 - val_loss: 0.6123 - val_accuracy: 0.8203 - lr: 0.0010
# Epoch 18/50
# 169/169 [==============================] - 7s 39ms/step - loss: 0.2920 - accuracy: 0.8917 - val_loss: 0.6016 - val_accuracy: 0.8322 - lr: 0.0010
# Epoch 19/50
# 169/169 [==============================] - 7s 39ms/step - loss: 0.3025 - accuracy: 0.8841 - val_loss: 0.6749 - val_accuracy: 0.8129 - lr: 0.0010
# Epoch 20/50
# 169/169 [==============================] - 7s 39ms/step - loss: 0.3128 - accuracy: 0.8819 - val_loss: 0.6516 - val_accuracy: 0.8211 - lr: 0.0010
# Epoch 21/50
# 169/169 [==============================] - ETA: 0s - loss: 0.3056 - accuracy: 0.8872
# Epoch 21: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 169/169 [==============================] - 7s 39ms/step - loss: 0.3056 - accuracy: 0.8872 - val_loss: 0.7186 - val_accuracy: 0.8203 - lr: 0.0010
# Epoch 22/50
# 169/169 [==============================] - 7s 39ms/step - loss: 0.2285 - accuracy: 0.9125 - val_loss: 0.6442 - val_accuracy: 0.8396 - lr: 5.0000e-04
# Epoch 23/50
# 169/169 [==============================] - 7s 39ms/step - loss: 0.2025 - accuracy: 0.9188 - val_loss: 0.6616 - val_accuracy: 0.8374 - lr: 5.0000e-04
# Epoch 24/50
# 169/169 [==============================] - 7s 39ms/step - loss: 0.1844 - accuracy: 0.9275 - val_loss: 0.6736 - val_accuracy: 0.8545 - lr: 5.0000e-04
# Epoch 25/50
# 169/169 [==============================] - 7s 39ms/step - loss: 0.1737 - accuracy: 0.9286 - val_loss: 0.6398 - val_accuracy: 0.8478 - lr: 5.0000e-04
# Epoch 26/50
# 169/169 [==============================] - 7s 39ms/step - loss: 0.1858 - accuracy: 0.9234 - val_loss: 0.7668 - val_accuracy: 0.8307 - lr: 5.0000e-04
# Epoch 27/50
# 169/169 [==============================] - ETA: 0s - loss: 0.1840 - accuracy: 0.9280
# Epoch 27: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 169/169 [==============================] - 7s 39ms/step - loss: 0.1840 - accuracy: 0.9280 - val_loss: 0.6978 - val_accuracy: 0.8396 - lr: 5.0000e-04
# Epoch 28/50
# 169/169 [==============================] - 7s 39ms/step - loss: 0.1393 - accuracy: 0.9440 - val_loss: 0.6752 - val_accuracy: 0.8560 - lr: 2.5000e-04
# Epoch 29/50
# 169/169 [==============================] - 7s 39ms/step - loss: 0.1428 - accuracy: 0.9382 - val_loss: 0.6467 - val_accuracy: 0.8604 - lr: 2.5000e-04
# Epoch 30/50
# 169/169 [==============================] - 7s 39ms/step - loss: 0.1459 - accuracy: 0.9392 - val_loss: 0.6833 - val_accuracy: 0.8612 - lr: 2.5000e-04
# Epoch 31/50
# 169/169 [==============================] - 7s 39ms/step - loss: 0.1355 - accuracy: 0.9457 - val_loss: 0.6534 - val_accuracy: 0.8627 - lr: 2.5000e-04
# Epoch 32/50
# 169/169 [==============================] - 7s 40ms/step - loss: 0.1355 - accuracy: 0.9416 - val_loss: 0.6628 - val_accuracy: 0.8716 - lr: 2.5000e-04
# Epoch 33/50
# 169/169 [==============================] - 7s 39ms/step - loss: 0.1250 - accuracy: 0.9468 - val_loss: 0.7065 - val_accuracy: 0.8575 - lr: 2.5000e-04
# Epoch 34/50
# 169/169 [==============================] - 7s 40ms/step - loss: 0.1288 - accuracy: 0.9473 - val_loss: 0.7231 - val_accuracy: 0.8530 - lr: 2.5000e-04
# Epoch 35/50
# 169/169 [==============================] - ETA: 0s - loss: 0.1233 - accuracy: 0.9483
# Epoch 35: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 169/169 [==============================] - 7s 39ms/step - loss: 0.1233 - accuracy: 0.9483 - val_loss: 0.6881 - val_accuracy: 0.8582 - lr: 2.5000e-04
# Epoch 36/50
# 169/169 [==============================] - 7s 39ms/step - loss: 0.1222 - accuracy: 0.9486 - val_loss: 0.7124 - val_accuracy: 0.8560 - lr: 1.2500e-04
# Epoch 37/50
# 169/169 [==============================] - 7s 39ms/step - loss: 0.1206 - accuracy: 0.9501 - val_loss: 0.7045 - val_accuracy: 0.8597 - lr: 1.2500e-04
# Epoch 38/50
# 169/169 [==============================] - ETA: 0s - loss: 0.1104 - accuracy: 0.9509
# Epoch 38: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 169/169 [==============================] - 7s 39ms/step - loss: 0.1104 - accuracy: 0.9509 - val_loss: 0.7364 - val_accuracy: 0.8641 - lr: 1.2500e-04
# Epoch 39/50
# 169/169 [==============================] - 7s 39ms/step - loss: 0.1104 - accuracy: 0.9522 - val_loss: 0.7159 - val_accuracy: 0.8649 - lr: 6.2500e-05
# Epoch 40/50
# 169/169 [==============================] - 7s 39ms/step - loss: 0.1140 - accuracy: 0.9527 - val_loss: 0.7020 - val_accuracy: 0.8612 - lr: 6.2500e-05
# Epoch 41/50
# 169/169 [==============================] - ETA: 0s - loss: 0.1083 - accuracy: 0.9522
# Epoch 41: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 169/169 [==============================] - 7s 39ms/step - loss: 0.1083 - accuracy: 0.9522 - val_loss: 0.7087 - val_accuracy: 0.8627 - lr: 6.2500e-05
# Epoch 42/50
# 169/169 [==============================] - 7s 39ms/step - loss: 0.1101 - accuracy: 0.9510 - val_loss: 0.7171 - val_accuracy: 0.8589 - lr: 3.1250e-05
# Epoch 43/50
# 169/169 [==============================] - 7s 39ms/step - loss: 0.1082 - accuracy: 0.9522 - val_loss: 0.7150 - val_accuracy: 0.8612 - lr: 3.1250e-05
# Epoch 44/50
# 169/169 [==============================] - ETA: 0s - loss: 0.1035 - accuracy: 0.9588
# Epoch 44: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 169/169 [==============================] - 7s 39ms/step - loss: 0.1035 - accuracy: 0.9588 - val_loss: 0.7089 - val_accuracy: 0.8604 - lr: 3.1250e-05
# Epoch 45/50
# 169/169 [==============================] - 7s 39ms/step - loss: 0.1017 - accuracy: 0.9559 - val_loss: 0.7169 - val_accuracy: 0.8612 - lr: 1.5625e-05
# Epoch 46/50
# 169/169 [==============================] - 7s 39ms/step - loss: 0.1030 - accuracy: 0.9585 - val_loss: 0.7218 - val_accuracy: 0.8612 - lr: 1.5625e-05
# Epoch 47/50
# 169/169 [==============================] - ETA: 0s - loss: 0.1033 - accuracy: 0.9540
# Epoch 47: ReduceLROnPlateau reducing learning rate to 1e-05.
# 169/169 [==============================] - 7s 39ms/step - loss: 0.1033 - accuracy: 0.9540 - val_loss: 0.7213 - val_accuracy: 0.8604 - lr: 1.5625e-05
# Epoch 48/50
# 169/169 [==============================] - 7s 39ms/step - loss: 0.1085 - accuracy: 0.9547 - val_loss: 0.7236 - val_accuracy: 0.8612 - lr: 1.0000e-05
# Epoch 49/50
# 169/169 [==============================] - 7s 39ms/step - loss: 0.1088 - accuracy: 0.9560 - val_loss: 0.7243 - val_accuracy: 0.8589 - lr: 1.0000e-05
# Epoch 50/50
# 169/169 [==============================] - 7s 39ms/step - loss: 0.1037 - accuracy: 0.9540 - val_loss: 0.7261 - val_accuracy: 0.8589 - lr: 1.0000e-05

# %% [markdown]
# #### **Todo:**  Visualize the model results

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# #### **Todo:**  Analyze your results here. Did you get rid of underfitting/overfitting? Did class rebalance help?
#
# Overfitting is reduced after Class rebalance and thus loss is being reduced.
#
# Accuracy of the model is 85%
#
# Used  dropout and ImageDataGenerator which reduced the over fit
#
# At last we tried Batch Normalization and Augumentation which really helped in carry forward
